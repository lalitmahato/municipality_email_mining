# %%
import requests
import time
from bs4 import BeautifulSoup
import json
import pandas as pd
import numpy as np
import re

# %%
url = 'https://sthaniya.gov.np/gis/website/webdataquery.php?province=0'
page = requests.get(url, timeout=1000, headers={'User-Agent': 'Mozilla/5.0'})
soup = BeautifulSoup(page.content, 'html.parser')

# %%
tbl = soup.find('table')

# %%
table = pd.read_html(str(tbl))[0]

# %%
table
# Out:
#      क्र.स.           स्थानीय तहको नाम                            जिल्ला  \
# 0         1           फुङलिङ नगरपालिका                         ताप्लेजुङ
# 1         2  आठराई त्रिवेणी गाउँपालिका                         ताप्लेजुङ
# 2         3        सिदिङ्वा गाउँपालिका                         ताप्लेजुङ
# 3         4       फक्ताङलुङ गाउँपालिका                         ताप्लेजुङ
# 4         5      मिक्वाखोला गाउँपालिका                         ताप्लेजुङ
# ..      ...                        ...                               ...
# 748     749            सुनवल नगरपालिका  नवलपरासी (बर्दघाट सुस्ता पश्चिम)
# 749     750          सुस्ता गाउँपालिका  नवलपरासी (बर्दघाट सुस्ता पश्चिम)
# 750     751     पाल्हीनन्दन गाउँपालिका  नवलपरासी (बर्दघाट सुस्ता पश्चिम)
# 751     752       प्रतापपुर गाउँपालिका  नवलपरासी (बर्दघाट सुस्ता पश्चिम)
# 752     753           सरावल गाउँपालिका  नवलपरासी (बर्दघाट सुस्ता पश्चिम)
#
#     स्थानीय तहको प्रकार           प्रदेश                   वेवसाईट कैफियत
# 0             नगरपालिका   प्रदेश नम्बर १       phunglingmun.gov.np   तयार
# 1            गाउँपालिका   प्रदेश नम्बर १  aathraitribenimun.gov.np   तयार
# 2            गाउँपालिका   प्रदेश नम्बर १        sidingbamun.gov.np   तयार
# 3            गाउँपालिका   प्रदेश नम्बर १    phaktanglungmun.gov.np   तयार
# 4            गाउँपालिका   प्रदेश नम्बर १      mikwakholamun.gov.np   तयार
# ..                  ...              ...                       ...    ...
# 748           नगरपालिका  लुम्बिनी प्रदेश          sunwalmun.gov.np   तयार
# 749          गाउँपालिका  लुम्बिनी प्रदेश           sustamun.gov.np   तयार
# 750          गाउँपालिका  लुम्बिनी प्रदेश     palhinandanmun.gov.np   तयार
# 751          गाउँपालिका  लुम्बिनी प्रदेश       pratappurmun.gov.np   तयार
# 752          गाउँपालिका  लुम्बिनी प्रदेश         sarawalmun.gov.np   तयार
#
# [753 rows x 7 columns]

# %%
whole_data = []
unable_to_scrap = []

# %%
table.columns
# Out:
# Index(['क्र.स.', 'स्थानीय तहको नाम', 'जिल्ला', 'स्थानीय तहको प्रकार', 'प्रदेश',
#        'वेवसाईट', 'कैफियत'],
#       dtype='object')

# %%
table_data = np.array(table)

# %%
table_data
# Out:
# array([[1, 'फुङलिङ नगरपालिका', 'ताप्लेजुङ', ..., 'प्रदेश नम्बर १',
#         'phunglingmun.gov.np', 'तयार'],
#        [2, 'आठराई त्रिवेणी गाउँपालिका', 'ताप्लेजुङ', ...,
#         'प्रदेश नम्बर १', 'aathraitribenimun.gov.np', 'तयार'],
#        [3, 'सिदिङ्वा गाउँपालिका', 'ताप्लेजुङ', ..., 'प्रदेश नम्बर १',
#         'sidingbamun.gov.np', 'तयार'],
#        ...,
#        [751, 'पाल्हीनन्दन गाउँपालिका',
#         'नवलपरासी (बर्दघाट सुस्ता पश्चिम)', ..., 'लुम्बिनी प्रदेश',
#         'palhinandanmun.gov.np', 'तयार'],
#        [752, 'प्रतापपुर गाउँपालिका', 'नवलपरासी (बर्दघाट सुस्ता पश्चिम)',
#         ..., 'लुम्बिनी प्रदेश', 'pratappurmun.gov.np', 'तयार'],
#        [753, 'सरावल गाउँपालिका', 'नवलपरासी (बर्दघाट सुस्ता पश्चिम)', ...,
#         'लुम्बिनी प्रदेश', 'sarawalmun.gov.np', 'तयार']], dtype=object)

# %%
def extractEmail(url):
    mun_page = requests.get(url, timeout=5000, headers={'User-Agent': 'Mozilla/5.0'})
    page_soup = BeautifulSoup(mun_page.content, 'html.parser')
    page_content = page_soup.text
    emails = re.findall(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b', page_content)
    emails = ', '.join(emails)
    return emails

# %%
# extractEmail('http://'+"phunglingmun.gov.np")

# %%
counter = 1
for td in table_data:
    print(counter)
    mun_url = 'http://'+td[5]
    print('Scrapping', 'http://'+td[5])
    try:
        email = extractEmail(mun_url)
        whole_data.append({
            'sn': td[0],
            'municipality': td[1],
            'District': td[2],
            'Local_level_Type': td[3],
            'Province': td[4],
            'website': mun_url,
            'Email': email,
        })
        counter = counter + 1
        print('Completed\n')
    except:
        unable_to_scrap.append(int(td[0])-1)
        print('unabel to scrap')
# Out:
# 1
# Scrapping http://phunglingmun.gov.np
# Completed
#
# 2
# Scrapping http://aathraitribenimun.gov.np
# Completed
#
# 3
# Scrapping http://sidingbamun.gov.np
# Completed
#
# 4
# Scrapping http://phaktanglungmun.gov.np
# Completed
#
# 5
# Scrapping http://mikwakholamun.gov.np
# Completed
#
# 6
# Scrapping http://meringdenmun.gov.np
# Completed
#
# 7
# Scrapping http://maiwakholamun.gov.np
# Completed
#
# 8
# Scrapping http://yangwarakmuntaplejung.gov.np
# Completed
#
# 9
# Scrapping http://sirijanghamun.gov.np
# Completed
#
# 10
# Scrapping http://phidimmun.gov.np
# Completed
#
# 11
# Scrapping http://phalelungmun.gov.np
# Completed
#
# 12
# Scrapping http://phalgunandamun.gov.np
# Completed
#
# 13
# Scrapping http://hilihangmun.gov.np
# Completed
#
# 14
# Scrapping http://kummayakmun.gov.np
# Completed
#
# 15
# Scrapping http://miklajungmunpanchthar.gov.np
# Completed
#
# 16
# Scrapping http://tumwewamun.gov.np
# Completed
#
# 17
# Scrapping http://yangwarakmunpanchthar.gov.np
# Completed
#
# 18
# Scrapping http://ilammun.gov.np
# Completed
#
# 19
# Scrapping http://deumaimun.gov.np
# Completed
#
# 20
# Scrapping http://maimun.gov.np
# Completed
#
# 21
# Scrapping http://suryodayamun.gov.np
# Completed
#
# 22
# Scrapping http://phakphokthummun.gov.np
# Completed
#
# 23
# Scrapping http://chulachulimun.gov.np
# Completed
#
# 24
# Scrapping http://maijogmaimun.gov.np
# Completed
#
# 25
# Scrapping http://mansebungmun.gov.np
# Completed
#
# 26
# Scrapping http://rongmun.gov.np
# Completed
#
# 27
# Scrapping http://sandakpurmun.gov.np
# Completed
#
# 28
# Scrapping http://mechinagarmun.gov.np
# Completed
#
# 29
# Scrapping http://damakmun.gov.np
# Completed
#
# 30
# Scrapping http://kankaimun.gov.np
# Completed
#
# 31
# Scrapping http://bhadrapurmun.gov.np
# Completed
#
# 32
# Scrapping http://arjundharamun.gov.np
# Completed
#
# 33
# Scrapping http://shivasatakshimun.gov.np
# Completed
#
# 34
# Scrapping http://gauradahamun.gov.np
# Completed
#
# 35
# Scrapping http://birtamodmun.gov.np
# Completed
#
# 36
# Scrapping http://kamalmun.gov.np
# Completed
#
# 37
# Scrapping http://gaurigunjmun.gov.np
# Completed
#
# 38
# Scrapping http://bahradashimun.gov.np
# Completed
#
# 39
# Scrapping http://jhapamun.gov.np
# Completed
#
# 40
# Scrapping http://buddhashantimun.gov.np
# Completed
#
# 41
# Scrapping http://haldibarimun.gov.np
# Completed
#
# 42
# Scrapping http://kachankawalmun.gov.np
# Completed
#
# 43
# Scrapping http://biratnagarmun.gov.np
# Completed
#
# 44
# Scrapping http://belbarimun.gov.np
# Completed
#
# 45
# Scrapping http://letangmun.gov.np
# Completed
#
# 46
# Scrapping http://patharishanishcharemun.gov.np
# Completed
#
# 47
# Scrapping http://rangelimun.gov.np
# Completed
#
# 48
# Scrapping http://ratuwamaimun.gov.np
# Completed
#
# 49
# Scrapping http://sunawarshimun.gov.np
# Completed
#
# 50
# Scrapping http://urlabarimun.gov.np
# Completed
#
# 51
# Scrapping http://sundarharaichamun.gov.np
# Completed
#
# 52
# Scrapping http://budhigangamunmorang.gov.np
# Completed
#
# 53
# Scrapping http://dhanapalthanmun.gov.np
# Completed
#
# 54
# Scrapping http://gramthanmun.gov.np
# Completed
#
# 55
# Scrapping http://jahadamun.gov.np
# Completed
#
# 56
# Scrapping http://kanepokharimun.gov.np
# Completed
#
# 57
# Scrapping http://kataharimun.gov.np
# Completed
#
# 58
# Scrapping http://kerabarimun.gov.np
# Completed
#
# 59
# Scrapping http://miklajungmunmorang.gov.np
# Completed
#
# 60
# Scrapping http://itaharimun.gov.np
# Completed
#
# 61
# Scrapping http://dharan.gov.np
# Completed
#
# 62
# Scrapping http://inaruwamun.gov.np
# Completed
#
# 63
# Scrapping http://duhabimun.gov.np
# Completed
#
# 64
# Scrapping http://ramdhunimun.gov.np
# Completed
#
# 65
# Scrapping http://barahamun.gov.np
# Completed
#
# 66
# Scrapping http://dewanganjmun.gov.np
# Completed
#
# 67
# Scrapping http://koshimun.gov.np
# Completed
#
# 68
# Scrapping http://gadhimun.gov.np
# Completed
#
# 69
# Scrapping http://barjumun.gov.np
# Completed
#
# 70
# Scrapping http://bhokrahamun.gov.np
# Completed
#
# 71
# Scrapping http://harinagaramun.gov.np
# Completed
#
# 72
# Scrapping http://pakhribasmun.gov.np
# Completed
#
# 73
# Scrapping http://dhankutamun.gov.np
# Completed
#
# 74
# Scrapping http://mahalaxmimundhankuta.gov.np
# Completed
#
# 75
# Scrapping http://sangurigadhimun.gov.np
# Completed
#
# 76
# Scrapping http://shahidbhumimun.gov.np
# Completed
#
# 77
# Scrapping http://chhatharjorpatimun.gov.np
# Completed
#
# 78
# Scrapping http://choubisemun.gov.np
# Completed
#
# 79
# Scrapping http://myanglungmun.gov.np
# Completed
#
# 80
# Scrapping http://laliguransmun.gov.np
# Completed
#
# 81
# Scrapping http://aathraimun.gov.np
# Completed
#
# 82
# Scrapping http://chhatharmun.gov.np
# Completed
#
# 83
# Scrapping http://phedapmun.gov.np
# Completed
#
# 84
# Scrapping http://menchhayayemmun.gov.np
# Completed
#
# 85
# Scrapping http://chainpurmun.gov.np
# Completed
#
# 86
# Scrapping http://dharmadevimun.gov.np
# Completed
#
# 87
# Scrapping http://khandbarimun.gov.np
# Completed
#
# 88
# Scrapping http://madimunsankhuwasabha.gov.np
# Completed
#
# 89
# Scrapping http://panchkhapanmun.gov.np
# Completed
#
# 90
# Scrapping http://bhotkholamun.gov.np
# Completed
#
# 91
# Scrapping http://chichilamun.gov.np
# Completed
#
# 92
# Scrapping http://makalumun.gov.np
# Completed
#
# 93
# Scrapping http://savapokharimun.gov.np
# Completed
#
# 94
# Scrapping http://silichongmun.gov.np
# Completed
#
# 95
# Scrapping http://bhojpurmun.gov.np
# Completed
#
# 96
# Scrapping http://shadanandamun.gov.np
# Completed
#
# 97
# Scrapping http://tyamkemaiyummun.gov.np
# Completed
#
# 98
# Scrapping http://ramprasadraimun.gov.np
# Completed
#
# 99
# Scrapping http://arunmun.gov.np
# Completed
#
# 100
# Scrapping http://pauwadungmamun.gov.np
# Completed
#
# 101
# Scrapping http://salpasilichhomun.gov.np
# Completed
#
# 102
# Scrapping http://aamchowkmun.gov.np
# Completed
#
# 103
# Scrapping http://hatuwagadhimun.gov.np
# Completed
#
# 104
# Scrapping http://solududhkundamun.gov.np
# Completed
#
# 105
# Scrapping http://dudhkoshimun.gov.np
# Completed
#
# 106
# Scrapping http://khumbupasanglhamumun.gov.np
# Completed
#
# 107
# Scrapping http://thulungdudhkoshimun.gov.np
# Completed
#
# 108
# Scrapping http://nechasalyanmun.gov.np
# Completed
#
# 109
# Scrapping http://mahakulungmun.gov.np
# Completed
#
# 110
# Scrapping http://likhupikemun.gov.np
# Completed
#
# 111
# Scrapping http://sotangmun.gov.np
# Completed
#
# 112
# Scrapping http://siddhicharanmun.gov.np
# Completed
#
# 113
# Scrapping http://khijidembamun.gov.np
# Completed
#
# 114
# Scrapping http://champadevimun.gov.np
# Completed
#
# 115
# Scrapping http://chishankhugadhimun.gov.np
# Completed
#
# 116
# Scrapping http://manebhanjyangmun.gov.np
# Completed
#
# 117
# Scrapping http://molungmun.gov.np
# Completed
#
# 118
# Scrapping http://likhumunokhaldhunga.gov.np
# Completed
#
# 119
# Scrapping http://sunkoshimunokhaldhunga.gov.np
# Completed
#
# 120
# Scrapping http://halesituwachungmun.gov.np
# Completed
#
# 121
# Scrapping http://rupakotmajhuwagadhimun.gov.np
# Completed
#
# 122
# Scrapping http://aiselukharkamun.gov.np
# Completed
#
# 123
# Scrapping http://rawabesimun.gov.np
# Completed
#
# 124
# Scrapping http://jantedhungamun.gov.np
# Completed
#
# 125
# Scrapping http://khotehangmun.gov.np
# Completed
#
# 126
# Scrapping http://kepilasgadhimun.gov.np
# Completed
#
# 127
# Scrapping http://diprungmun.gov.np
# Completed
#
# 128
# Scrapping http://sakelamun.gov.np
# Completed
#
# 129
# Scrapping http://barahapokharimun.gov.np
# Completed
#
# 130
# Scrapping http://katarimun.gov.np
# Completed
#
# 131
# Scrapping http://chaudandigadhimun.gov.np
# Completed
#
# 132
# Scrapping http://triyugamun.gov.np
# Completed
#
# 133
# Scrapping http://belakamun.gov.np
# Completed
#
# 134
# Scrapping http://udayapurgadhimun.gov.np
# Completed
#
# 135
# Scrapping http://taplimun.gov.np
# Completed
#
# 136
# Scrapping http://rautamaimun.gov.np
# Completed
#
# 137
# Scrapping http://sunkoshimunudayapur.gov.np
# Completed
#
# 138
# Scrapping http://rajbirajmun.gov.np
# Completed
#
# 139
# Scrapping http://kanchanrupmun.gov.np
# Completed
#
# 140
# Scrapping http://dakneshworimun.gov.np
# Completed
#
# 141
# Scrapping http://bodebarsainmun.gov.np
# Completed
#
# 142
# Scrapping http://khadakmun.gov.np
# Completed
#
# 143
# Scrapping http://shambhunathmun.gov.np
# Completed
#
# 144
# Scrapping http://surungamun.gov.np
# Completed
#
# 145
# Scrapping http://hanumannagarkankalinimun.gov.np
# Completed
#
# 146
# Scrapping http://saptakoshimun.gov.np
# Completed
#
# 147
# Scrapping http://agnisairkrishnasawaranmun.gov.np
# Completed
#
# 148
# Scrapping http://chhinnamastamun.gov.np
# Completed
#
# 149
# Scrapping http://mahadevamun.gov.np
# Completed
#
# 150
# Scrapping http://tirahutmun.gov.np
# Completed
#
# 151
# Scrapping http://tilathikoiladimun.gov.np
# Completed
#
# 152
# Scrapping http://rupanimun.gov.np
# Completed
#
# 153
# Scrapping http://rajgadhmun.gov.np
# Completed
#
# 154
# Scrapping http://bishnupurmunsaptari.gov.np
# Completed
#
# 155
# Scrapping http://balanbihulmun.gov.np
# Completed
#
# 156
# Scrapping http://lahanmun.gov.np
# Completed
#
# 157
# Scrapping http://dhangadhimaimun.gov.np
# Completed
#
# 158
# Scrapping http://sirahamun.gov.np
# Completed
#
# 159
# Scrapping http://golbazarmun.gov.np
# Completed
#
# 160
# Scrapping http://mirchaiyamun.gov.np
# Completed
#
# 161
# Scrapping http://kalyanpurmun.gov.np
# Completed
#
# 162
# Scrapping http://karjanhamun.gov.np
# Completed
#
# 163
# Scrapping http://sukhipurmun.gov.np
# Completed
#
# 164
# Scrapping http://bhagwanpurmun.gov.np
# Completed
#
# 165
# Scrapping http://aurahimunsiraha.gov.np
# Completed
#
# 166
# Scrapping http://bishnupurmunsiraha.gov.np
# Completed
#
# 167
# Scrapping http://bariyapattimun.gov.np
# Completed
#
# 168
# Scrapping http://laxmipurpatarimun.gov.np
# Completed
#
# 169
# Scrapping http://narahamun.gov.np
# Completed
#
# 170
# Scrapping http://sakhuwanankarkattimun.gov.np
# Completed
#
# 171
# Scrapping http://anarmamun.gov.np
# Completed
#
# 172
# Scrapping http://nawarajpurmun.gov.np
# Completed
#
# 173
# Scrapping http://janakpurmun.gov.np
# Completed
#
# 174
# Scrapping http://kshireshwornathmun.gov.np
# Completed
#
# 175
# Scrapping http://ganeshmancharnathmun.gov.np
# Completed
#
# 176
# Scrapping http://dhanushadhammun.gov.np
# Completed
#
# 177
# Scrapping http://nagrainmun.gov.np
# Completed
#
# 178
# Scrapping http://bidehamun.gov.np
# Completed
#
# 179
# Scrapping http://mithilamun.gov.np
# Completed
#
# 180
# Scrapping http://shahidnagarmun.gov.np
# Completed
#
# 181
# Scrapping http://sabailamun.gov.np
# Completed
#
# 182
# Scrapping http://kamalamun.gov.np
# Completed
#
# 183
# Scrapping http://mithilabiharimun.gov.np
# Completed
#
# 184
# Scrapping http://hansapurmun.gov.np
# Completed
#
# 185
# Scrapping http://janaknandinimun.gov.np
# Completed
#
# 186
# Scrapping http://bateshwormun.gov.np
# Completed
#
# 187
# Scrapping http://mukhiyapattimusaharmiyamun.gov.np
# Completed
#
# 188
# Scrapping http://laxminiyamun.gov.np
# Completed
#
# 189
# Scrapping http://aurahimundhanusha.gov.np
# Completed
#
# 190
# Scrapping http://dhanaujimun.gov.np
# Completed
#
# 191
# Scrapping http://jaleshwormun.gov.np
# Completed
#
# 192
# Scrapping http://bardibasmun.gov.np
# Completed
#
# 193
# Scrapping http://gaushalamun.gov.np
# Completed
#
# 194
# Scrapping http://loharpattimun.gov.np
# Completed
#
# 195
# Scrapping http://ramgopalpurmun.gov.np
# Completed
#
# 196
# Scrapping http://manrashiswamun.gov.np
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File ~\anaconda3\lib\socket.py:954, in getaddrinfo(host, port, family, type, proto, flags)
#     953 addrlist = []
# --> 954 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:398, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397     else:
# --> 398         conn.request(method, url, **httplib_request_kw)
#     400 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     401 # legitimately able to close the connection after sending a valid response.
#     402 # With this behaviour, the received response is still readable.
#
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:239, in HTTPConnection.request(self, method, url, body, headers)
#     238     headers["User-Agent"] = _get_default_user_agent()
# --> 239 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File ~\anaconda3\lib\http\client.py:1285, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1284 """Send a complete request to the server."""
# -> 1285 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\anaconda3\lib\http\client.py:1331, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1330     body = _encode(body, 'body')
# -> 1331 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\lib\http\client.py:1280, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1279     raise CannotSendHeader()
# -> 1280 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\lib\http\client.py:1040, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1039 del self._buffer[:]
# -> 1040 self.send(msg)
#    1042 if message_body is not None:
#    1043
#    1044     # create a consistent interface to message_body
#
# File ~\anaconda3\lib\http\client.py:980, in HTTPConnection.send(self, data)
#     979 if self.auto_open:
# --> 980     self.connect()
#     981 else:
#
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:205, in HTTPConnection.connect(self)
#     204 def connect(self):
# --> 205     conn = self._new_conn()
#     206     self._prepare_conn(conn)
#
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000001D060310C10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     439 if not chunked:
# --> 440     resp = conn.urlopen(
#     441         method=request.method,
#     442         url=url,
#     443         body=request.body,
#     444         headers=request.headers,
#     445         redirect=False,
#     446         assert_same_host=False,
#     447         preload_content=False,
#     448         decode_content=False,
#     449         retries=self.max_retries,
#     450         timeout=timeout
#     451     )
#     453 # Send the request.
#     454 else:
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File ~\anaconda3\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='manrashiswamun.gov.np', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001D060310C10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Input In [12], in <cell line: 2>()
#       5 print('Scrapping', 'http://'+td[5])
#       6 try:
# ----> 7     email = extractEmail(mun_url)
#       8     whole_data.append({
#       9         'sn': td[0],
#      10         'municipality': td[1],
#    (...)
#      15         'Email': email,
#      16     })
#      17     counter = counter + 1
#
# Input In [10], in extractEmail(url)
#       1 def extractEmail(url):
# ----> 2     mun_page = requests.get(url, timeout=5000, headers={'User-Agent': 'Mozilla/5.0'})
#       3     page_soup = BeautifulSoup(mun_page.content, 'html.parser')
#       4     page_content = page_soup.text
#
# File ~\anaconda3\lib\site-packages\requests\api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~\anaconda3\lib\site-packages\requests\adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='manrashiswamun.gov.np', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001D060310C10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %%
whole_data

# %%
email_df = pd.DataFrame(whole_data)

# %%
email_df.to_excel("municipality.xlsx")

# %%
unable_to_scrap

# %%
email_df
